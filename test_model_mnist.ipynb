# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('./gdrive/MyDrive/AEGAN/AE_GAN_CS')
# !nvidia-smi
# !ls

# %%
# %%shell
# for ((i=1; i<=8; i++))
# do
#   echo ${i}
#   python test_model_mnist.py --eps 0.1 --gan_path ./checkpoint/mnist/${i}.tar
# done
# Out:
# 1
# Accuracy: normal 98.589996, fgsm 82.489998, ape 98.409996
# 2
# Accuracy: normal 98.369995, fgsm 82.470001, ape 99.250000
# 3
# Accuracy: normal 98.430000, fgsm 82.520004, ape 99.419998
# 4
# Accuracy: normal 98.519997, fgsm 83.110001, ape 99.449997
# 5
# Accuracy: normal 98.570000, fgsm 82.700005, ape 99.470001
# 6
# Accuracy: normal 98.400002, fgsm 82.810005, ape 99.459999
# 7
# Accuracy: normal 98.589996, fgsm 82.680000, ape 99.379997
# 8
# Accuracy: normal 98.549995, fgsm 82.790001, ape 99.519997
