# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('./gdrive/MyDrive/AEGAN/AE_GAN_CS')
# !nvidia-smi
# !ls

# %%
# %%shell
# for ((i=1; i<=61; i++))
# do
#   echo ${i}
#   python test_model_cifar.py --eps 0.01 --gan_path ./checkpoint/cifar/${i}.tar
# done
# Out:
# 1
# Accuracy: normal 83.980003, fgsm 9.450000, ape 75.199997
# 2
# Accuracy: normal 83.980003, fgsm 9.450000, ape 75.239998
# 3
# Accuracy: normal 83.980003, fgsm 9.450000, ape 79.250000
# 4
# Accuracy: normal 83.980003, fgsm 9.450000, ape 79.919998
# 5
# Accuracy: normal 83.980003, fgsm 9.450000, ape 80.750000
# 6
# Accuracy: normal 83.980003, fgsm 9.450000, ape 79.449997
# 7
# Accuracy: normal 83.980003, fgsm 9.450000, ape 79.900002
# 8
# Accuracy: normal 83.980003, fgsm 9.450000, ape 80.580002
# 9
# Accuracy: normal 83.980003, fgsm 9.450000, ape 80.199997
# 10
# Accuracy: normal 83.980003, fgsm 9.450000, ape 80.510002
# 11
# Accuracy: normal 83.980003, fgsm 9.450000, ape 80.330002
# 12
# Accuracy: normal 83.980003, fgsm 9.450000, ape 80.360001
# 13
# Accuracy: normal 83.980003, fgsm 9.450000, ape 80.449997
# 14
# Accuracy: normal 83.980003, fgsm 9.450000, ape 80.199997
# 15
# Accuracy: normal 83.980003, fgsm 9.450000, ape 80.529999
# 16
# ...
