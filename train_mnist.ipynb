# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('./gdrive/MyDrive/AEGAN/AE_GAN_CS')
# !nvidia-smi
# !ls

# %%
# %%shell
# python train_mnist.py
# Out:
# 2021-02-08 19:23:47.213926: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Epoch	Gen_Loss	Dis_Loss
#   0% 0/1875 [00:00<?, ?it/s]/content/gdrive/My Drive/AEGAN/英文_基于GAN的图像对抗样本防御/models.py:160: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return h_out, F.softmax(cls)
# 0	1.217210	1.174150
# 1	1.490404	0.314685
# 2	1.469311	0.300779
# 3	1.497538	0.281659
# 4	1.464531	0.283414
# 5	1.477165	0.259566
# 6	1.462570	0.277479
# 7	1.458616	0.263610
# 8	1.458569	0.258973
# 9	1.461083	0.276719
# 10	1.449247	0.269831
# 11	1.457951	0.267069
# 12	1.463016	0.260897
# 13	1.458667	0.265040
# 14	1.442175	0.274470
# 15	1.452423	0.262085
# 16	1.440993	0.272740
# 17	1.452168	0.268196
# 18	1.446239	0.262996
# 19	1.447493	0.271483
# train_mnist.py:39: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(3, 5, figsize=(10, 6))
# 20	1.446607	0.266855
# 21	1.449489	0.267320
# 22	1.437672	0.275228
# 23	1.447676	0.268777
# 24	1.440013	0.272278
# 25	1.445773	0.265076
# 26	1.436553	0.277418
# 27	1.442756	0.267248
# 28	1.436435	0.271050
# 29	1.444164	0.268528
# 30	1.438707	0.272410
# 31	1.437113	0.272224
# 32	1.440358	0.267956
# 33	1.436765	0.270691
# 34	1.445260	0.269502
# 35	1.437130	0.268036
# 36	1.437813	0.269462
# 37	1.440141	0.267421
# 38	1.437661	0.266982
# 39	1.443077	0.266929
# 40	1.438007	0.267396
# 41	1.437461	0.268388
# 42	1.438146	0.265642
# 43	1.438021	0.266207
# 44	1.438383	0.267150
# 45	1.437516	0.266342
# 46	1.437702	0.267198
# 47	1.440816	0.263485
# 48	1.437282	0.265051
# 49	1.438158	0.264948
# 50	1.438099	0.264893
# 51	1.441540	0.265077
# 52	1.437090	0.263545
# 53	1.438286	0.263687
# 54	1.438408	0.263369
# 55	1.438641	0.261929
# 56	1.438562	0.263379
# 57	1.438607	0.262718
# 58	1.438551	0.261987
# 59	1.438569	0.263209
# 60	1.438621	0.261542
# 61	1.438677	0.261694
# 62	1.438654	0.261683
# 63	1.438742	0.259632
# 64	1.438913	0.260094
# 65	1.439102	0.259429
# 66	1.438746	0.258510
# 67	1.439117	0.259545
# 68	1.439387	0.257720
# 69	1.438997	0.257028
# 70	1.438869	0.258958
# 71	1.439075	0.258871
# 72	1.438987	0.257312
# 73	1.438945	0.258591
# 74	1.439035	0.258517
# 75	1.439101	0.257079
# 76	1.438910	0.257301
# 77	1.439027	0.257821
# 78	1.438803	0.257407
# 79	1.439017	0.256859
# 80	1.439150	0.255705
# 81	1.439053	0.256198
# 82	1.439080	0.256423
# 83	1.439168	0.256280
# 84	1.439207	0.255502
# 85	1.439547	0.254687
# 86	1.439536	0.256421
# 87	1.438990	0.255646
# 88	1.438867	0.256122
# 89	1.438890	0.254789
# 90	1.438692	0.254684
#  90% 1685/1875 [02:21<00:15, 11.90it/s]
